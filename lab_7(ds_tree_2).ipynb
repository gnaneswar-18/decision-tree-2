# %% [markdown]
# <a href="https://colab.research.google.com/github/gnaneswar-18/decision-tree-2/blob/main/lab_7(ds_tree_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import graphviz

data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/labs/Enjoy sports.csv')
x = data[['Outlook', 'Temp.', 'Humidity', 'Wind']]
y = data['Decision']

le = LabelEncoder()
x = x.apply(le.fit_transform)
y = le.fit_transform(y)

tree = DecisionTreeClassifier(criterion='entropy', random_state=0)
tree.fit(x, y)
dot_data = export_graphviz(tree, out_file=None,
                           feature_names=['Outlook', 'Temp.', 'Humidity', 'Wind'],
                           class_names=['No', 'Yes'],
                           filled=True, rounded=True,
                           special_characters=True)
graph = graphviz.Source(dot_data)

graph.render("decision_tree")
graph
